# %% [markdown]
# # Dictionaries and Words

# %%
#@title Run this cell before running the cells below
import math
def check(actual, expected):
  if math.isclose(actual, expected, rel_tol=1e-02):
    print(f'{actual} ✔️')
  else:
    print(f'Expected: "{expected}", Actual: "{actual}" ❌')

# %% [markdown]
# ## Anscombe’s Quartet JSON
#
# The file **'sample_data/anscombe.json'** contains the  Anscombe's Quartet series data in JSON format: 4 series of X, Y number pairs. Write a function that reads the file, and calculates the average X and Y values for each series. Additionally you can also calculate the standard deviation. The function should return a dictionary of dictionaries such that the mean for a series can be retrieved with:
#
# `results['I']['X']['avg']`.

# %%
# Write the function summarise_anscombe here

# %%
results = summarise_anscombe()
check(results['I']['X']['avg'], results['II']['X']['avg'])
check(results['I']['Y']['avg'], results['II']['Y']['avg'])
check(results['III']['X']['avg'], results['IV']['X']['avg'])
check(results['III']['Y']['avg'], results['IV']['Y']['avg'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-d24dcf262e43> in <module>()
# ----> 1 check(summarise_anscombe(results['I']['X']['avg']), results['II']['X']['avg'])
#       2 check(summarise_anscombe(results['I']['Y']['avg']), results['II']['Y']['avg'])
#       3 check(summarise_anscombe(results['III']['X']['avg']), results['IV']['X']['avg'])
#       4 check(summarise_anscombe(results['III']['Y']['avg']), results['IV']['Y']['avg'])
#
# NameError: name 'check' is not defined

# %% [markdown]
# ## Mimic
#
# Upload the file 'alice.txt' to the notebook's files. The file contains the book 'Alice in Wonderland'
#
# Write a series of functions that does the following:
# - reads the from the file system.
# - parses all words in the file by splitting on whitespace.
# - build a 'mimic' dictionary: a dictionary containing each word in the file mapped to a list of all words that immediately follow the word in the text.
#   - Assume the empty string is the word that preceeds the first word in the file.
# - using the mimic dictionary, generate a random mimic copy of the book:
#   - starting with the empty string, look up the list of words that follows it, and then choose one at random and print it. Repeat for the chosen word.

# %%
# Write your functions here.
